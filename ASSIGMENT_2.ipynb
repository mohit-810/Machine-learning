# %%
import numpy as np

#Question 1

a1= np.random.rand(10,1) #Creating an Array with shape (10,1)
print("Mean : ",np.mean(a1)) #Calculating Mean Using Basic Functions Of numpy
# Out:
# Mean :  0.40777904317344743

# %%
#Question 2

a2=np.random.rand(20,1)
print("Standard Deviation : ",np.std(a2)) #Calculating Standard Deviation
print("Variance : ",np.var(a2)) #Calculating Variance
# Out:
# Standard Deviation :  0.16986956090254324
# Variance :  0.02885566772122285

# %%
#Question 3

a3=np.random.rand(10,20)
a4=np.random.rand(20,25)
Matrix = a3.dot(a4) # Matrix multiplication
print(Matrix.shape)
print (Matrix)
print("Sum is : ", np.sum(Matrix))
# Out:
# (10, 25)
# [[3.93461741 6.45157451 5.0243166  4.8742462  5.22026364 4.78416481
#   4.11022131 3.06288194 5.16649325 4.28130567 5.04911721 4.31602884
#   4.20539437 4.49673382 4.85121166 3.80379286 6.5619137  5.0151502
#   4.90123628 4.57048998 4.84432238 4.61746167 4.24984237 5.11814742
#   4.33455485]
#  [4.43986703 5.59449822 4.66824221 5.31009577 3.99095245 3.77464631
#   4.37869865 3.99243902 4.62595269 3.61582097 4.46690964 5.05400228
#   3.76245864 4.10487599 4.86716621 4.28872401 5.36167586 4.86591708
#   4.59703933 4.3333235  4.81395787 3.66366175 3.69247002 5.38115239
#   3.56341633]
#  [4.63340019 7.15569052 5.7883071  5.94574384 4.80277615 5.19185815
#   4.45251338 4.28515205 6.17309871 5.3122681  5.87722132 5.38206024
#   4.57916693 5.40453527 6.15137212 4.63547182 7.18026872 5.68346374
#   5.49135151 5.87011465 6.26556157 5.12061343 4.78884719 6.1939737
#   5.21510516]
#  [4.34529986 6.40889091 6.21287962 6.08241192 5.89029482 5.65226411
# ...

# %%
# Question 4

a4 = np.random.rand(10, 1)
a5=[]
for i in a4:
    i=1/(1 + np.exp(-i))
    a5.append(list(i))
a5
# Out:
# [[0.7205675446068459],
#  [0.5388064434884904],
#  [0.5597015022020417],
#  [0.6508774566507736],
#  [0.5437336770629395],
#  [0.6363181929690468],
#  [0.6377488923053086],
#  [0.6071550814530646],
#  [0.5004458453135477],
#  [0.6824340684686878]]
